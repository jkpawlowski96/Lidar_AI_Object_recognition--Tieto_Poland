# %%
import metrics
import numpy as np

# %%
y = np.array([1, 1, 0, 1, 1, 0, 0, 0, 1])
pred = np.array([1, 0, 0, 1, 0, 1, 0, 0, 1])

# %%
metrics.score(y,pred)
# Out:
# (0.6666666666666665, 0.675, 0.675, 0.5555555555555556)
